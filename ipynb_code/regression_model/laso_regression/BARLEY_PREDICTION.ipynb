# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import MinMaxScaler

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
FinBar = pd.read_csv('C:/Users/hp/FIN_DATA/FinBar.csv')
FinBar.head()
# Out:
#    Unnamed: 0  Zone  Year     PRECIP     TMPMAX     TMPMIN     RELHUM  \
# 0           0     1  1997  69.269978  29.656865  14.336538  52.592245
# 1           1     2  1997  57.647542  29.802796  19.996551  45.495155
# 2           2     3  1997  34.947796  24.863651   9.024471  57.551787
# 3           3     4  1997  60.206309  38.878724  26.824670  47.743268
# 4           4     1  1998  78.737179  27.805128  18.107981  52.592245
#
#       WINDLY     SUNHRS  Irrg_Yes  Irrg_No  Seed_Improved  Seed_Not_Improved  \
# 0   1.698718  12.359170       0.0     72.0            0.0               72.0
# 1   1.698718  34.862082      14.0   1449.0            6.0             1457.0
# 2   7.858578  12.400941      25.0   2474.0           27.0             2472.0
# 3  10.645464  18.271932       0.0     74.0            0.0               74.0
# 4   1.575641  11.397638       0.0     72.0            0.0               72.0
#
#    Damage_Yes  Damage_No  Dreason_Crop_disease  Dreason_Frost  Dreason_Floods  \
# 0        22.0       48.0                   0.0            0.0             0.0
# 1       880.0      582.0                  31.0            7.0            10.0
# 2      2129.0      370.0                   3.0            3.0             4.0
# 3         1.0       73.0                   0.0            0.0             1.0
# 4        22.0       48.0                   0.0            0.0             0.0
#
#    Dreason_Locust  Dreason_Insects  Dreason_Toolittle_rain  \
# 0             0.0              4.0                    12.0
# 1            37.0            223.0                   343.0
# 2             2.0            764.0                  1259.0
# 3             0.0              0.0                     0.0
# 4             0.0              4.0                    12.0
#
#    Dreason_Toomuch_rain  Dreason_Wild_animals  Dreason_Birds  Dreason_Hail  \
# 0                   0.0                   1.0            0.0           2.0
# 1                  37.0                   8.0           60.0          79.0
# 2                  14.0                  12.0           11.0          29.0
# 3                   0.0                   0.0            0.0           0.0
# 4                   0.0                   1.0            0.0           2.0
#
#    Dreason_Weeds  Dreason_ShortageSeed  Dreason_DepletionSoil  \
# 0            1.0                   1.0                    1.0
# 1            9.0                   0.0                   21.0
# 2            6.0                   0.0                    9.0
# 3            0.0                   0.0                    0.0
# 4            1.0                   1.0                    1.0
#
#    Dreason_Security  Dreason_UseBadCrop  Dmeasure_Yes  Dmeasure_No  \
# 0               0.0                 0.0          71.0          0.0
# 1               0.0                15.0        1430.0         32.0
# 2               0.0                13.0        2465.0         34.0
# 3               0.0                 0.0          73.0          1.0
# 4               0.0                 0.0          71.0          0.0
#
#    Dmtype_Chemical  Dmtype_NonChemical  Dmtype_Both  Dmchem_Insecticide  \
# 0              0.0                70.0          1.0                 0.0
# 1             42.0              1303.0         85.0                20.0
# 2              7.0              2447.0         11.0                 0.0
# 3              0.0                73.0          0.0                 0.0
# 4              0.0                70.0          1.0                 0.0
#
#    Dmchem_Herbicide  Dmchem_Fungicide  Dmchem_Insectcide_Her  \
# 0               0.0               0.0                    0.0
# 1              14.0               0.0                    4.0
# 2               2.0               0.0                    0.0
# 3               0.0               0.0                    0.0
# 4               0.0               0.0                    0.0
#
#    Dmchem_Insectcide_Fun  Dmchem_Herbicide_Fung  Dmchem_All  Fert_Yes  \
# 0                    0.0                    0.0         0.0      22.0
# 1                    0.0                    0.0         0.0    1103.0
# 2                    0.0                    0.0         0.0    1809.0
# 3                    0.0                    0.0         0.0      52.0
# 4                    0.0                    0.0         0.0      22.0
#
#    Fert_No  Ferttype_Natural  Ferttype_Chemical  Ferttype_Both  D22a_Urea  \
# 0     50.0              16.0                6.0            0.0        0.0
# 1    360.0             648.0              246.0          196.0       18.0
# 2    690.0            1110.0              401.0          297.0       58.0
# 3     22.0              43.0                9.0            0.0        0.0
# 4     50.0              16.0                6.0            0.0        0.0
#
#    D22a_DAP  D22a_Urea_DAP  D22a_NPS  D22a_Urea_NPS  D22a_Mixed  D23_Manure  \
# 0       0.0            6.0       0.0            0.0         0.0        13.0
# 1      12.0          408.0       0.0            0.0         0.0       570.0
# 2     128.0          510.0       0.0            0.0         0.0       978.0
# 3       0.0            7.0       0.0            0.0         0.0        29.0
# 4       0.0            6.0       0.0            0.0         0.0        13.0
#
#    D23_Compost  D23_Organic  D23_Manure_Compost  D23_Manure_Organic  \
# 0          1.0          0.0                 1.0                 0.0
# 1         81.0          0.0               177.0                 0.0
# 2        255.0          0.0               156.0                 0.0
# 3         10.0          0.0                 4.0                 0.0
# 4          1.0          0.0                 1.0                 0.0
#
#    D23_Compost_Organic  D23_All    Fweight          Area  Production  \
# 0                  0.0      0.0   10983.27    500.000000     1863.00
# 1                  0.0      0.0  305751.82  20893.000000   207514.00
# 2                  0.0      0.0  348274.08  25691.000000   223088.00
# 3                  0.0      0.0    6040.31   2414.881429    24166.85
# 4                  0.0      0.0   10983.27    587.580000     5000.41
#
#        Yield
# 0   3.730000
# 1   9.930000
# 2   8.680000
# 3  10.007469
# 4   8.510000

# %%
# Let's separate into train and test set
# Remember to set the seed (random_state for this sklearn function)

X_train, X_test, y_train, y_test = train_test_split(FinBar, FinBar.Production,
                                                    test_size=0.2,
                                                    random_state=0) # we are setting the seed here
X_train.shape, X_test.shape
# Out:
# ((41, 64), (11, 64))

# %%
FinBar.head()
# Out:
#    Unnamed: 0  Zone  Year     PRECIP     TMPMAX     TMPMIN     RELHUM  \
# 0           0     1  1997  69.269978  29.656865  14.336538  52.592245
# 1           1     2  1997  57.647542  29.802796  19.996551  45.495155
# 2           2     3  1997  34.947796  24.863651   9.024471  57.551787
# 3           3     4  1997  60.206309  38.878724  26.824670  47.743268
# 4           4     1  1998  78.737179  27.805128  18.107981  52.592245
#
#       WINDLY     SUNHRS  Irrg_Yes  Irrg_No  Seed_Improved  Seed_Not_Improved  \
# 0   1.698718  12.359170       0.0     72.0            0.0               72.0
# 1   1.698718  34.862082      14.0   1449.0            6.0             1457.0
# 2   7.858578  12.400941      25.0   2474.0           27.0             2472.0
# 3  10.645464  18.271932       0.0     74.0            0.0               74.0
# 4   1.575641  11.397638       0.0     72.0            0.0               72.0
#
#    Damage_Yes  Damage_No  Dreason_Crop_disease  Dreason_Frost  Dreason_Floods  \
# 0        22.0       48.0                   0.0            0.0             0.0
# 1       880.0      582.0                  31.0            7.0            10.0
# 2      2129.0      370.0                   3.0            3.0             4.0
# 3         1.0       73.0                   0.0            0.0             1.0
# 4        22.0       48.0                   0.0            0.0             0.0
#
#    Dreason_Locust  Dreason_Insects  Dreason_Toolittle_rain  \
# 0             0.0              4.0                    12.0
# 1            37.0            223.0                   343.0
# 2             2.0            764.0                  1259.0
# 3             0.0              0.0                     0.0
# 4             0.0              4.0                    12.0
#
#    Dreason_Toomuch_rain  Dreason_Wild_animals  Dreason_Birds  Dreason_Hail  \
# 0                   0.0                   1.0            0.0           2.0
# 1                  37.0                   8.0           60.0          79.0
# 2                  14.0                  12.0           11.0          29.0
# 3                   0.0                   0.0            0.0           0.0
# 4                   0.0                   1.0            0.0           2.0
#
#    Dreason_Weeds  Dreason_ShortageSeed  Dreason_DepletionSoil  \
# 0            1.0                   1.0                    1.0
# 1            9.0                   0.0                   21.0
# 2            6.0                   0.0                    9.0
# 3            0.0                   0.0                    0.0
# 4            1.0                   1.0                    1.0
#
#    Dreason_Security  Dreason_UseBadCrop  Dmeasure_Yes  Dmeasure_No  \
# 0               0.0                 0.0          71.0          0.0
# 1               0.0                15.0        1430.0         32.0
# 2               0.0                13.0        2465.0         34.0
# 3               0.0                 0.0          73.0          1.0
# 4               0.0                 0.0          71.0          0.0
#
#    Dmtype_Chemical  Dmtype_NonChemical  Dmtype_Both  Dmchem_Insecticide  \
# 0              0.0                70.0          1.0                 0.0
# 1             42.0              1303.0         85.0                20.0
# 2              7.0              2447.0         11.0                 0.0
# 3              0.0                73.0          0.0                 0.0
# 4              0.0                70.0          1.0                 0.0
#
#    Dmchem_Herbicide  Dmchem_Fungicide  Dmchem_Insectcide_Her  \
# 0               0.0               0.0                    0.0
# 1              14.0               0.0                    4.0
# 2               2.0               0.0                    0.0
# 3               0.0               0.0                    0.0
# 4               0.0               0.0                    0.0
#
#    Dmchem_Insectcide_Fun  Dmchem_Herbicide_Fung  Dmchem_All  Fert_Yes  \
# 0                    0.0                    0.0         0.0      22.0
# 1                    0.0                    0.0         0.0    1103.0
# 2                    0.0                    0.0         0.0    1809.0
# 3                    0.0                    0.0         0.0      52.0
# 4                    0.0                    0.0         0.0      22.0
#
#    Fert_No  Ferttype_Natural  Ferttype_Chemical  Ferttype_Both  D22a_Urea  \
# 0     50.0              16.0                6.0            0.0        0.0
# 1    360.0             648.0              246.0          196.0       18.0
# 2    690.0            1110.0              401.0          297.0       58.0
# 3     22.0              43.0                9.0            0.0        0.0
# 4     50.0              16.0                6.0            0.0        0.0
#
#    D22a_DAP  D22a_Urea_DAP  D22a_NPS  D22a_Urea_NPS  D22a_Mixed  D23_Manure  \
# 0       0.0            6.0       0.0            0.0         0.0        13.0
# 1      12.0          408.0       0.0            0.0         0.0       570.0
# 2     128.0          510.0       0.0            0.0         0.0       978.0
# 3       0.0            7.0       0.0            0.0         0.0        29.0
# 4       0.0            6.0       0.0            0.0         0.0        13.0
#
#    D23_Compost  D23_Organic  D23_Manure_Compost  D23_Manure_Organic  \
# 0          1.0          0.0                 1.0                 0.0
# 1         81.0          0.0               177.0                 0.0
# 2        255.0          0.0               156.0                 0.0
# 3         10.0          0.0                 4.0                 0.0
# 4          1.0          0.0                 1.0                 0.0
#
#    D23_Compost_Organic  D23_All    Fweight          Area  Production  \
# 0                  0.0      0.0   10983.27    500.000000     1863.00
# 1                  0.0      0.0  305751.82  20893.000000   207514.00
# 2                  0.0      0.0  348274.08  25691.000000   223088.00
# 3                  0.0      0.0    6040.31   2414.881429    24166.85
# 4                  0.0      0.0   10983.27    587.580000     5000.41
#
#        Yield
# 0   3.730000
# 1   9.930000
# 2   8.680000
# 3  10.007469
# 4   8.510000

# %%
for var in ['PRECIP', 'TMPMAX', 'TMPMIN', 'RELHUM', 'WINDLY', 'SUNHRS', 'Fweight', 'Area', 'Production', 'Yield']:
    X_train[var] = np.log(X_train[var])
    X_test[var]= np.log(X_test[var])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# check that test set does not contain null values in the engineered variables
[var for var in ['PRECIP', 'TMPMAX', 'TMPMIN', 'RELHUM', 'WINDLY', 'SUNHRS', 'Seed_Not_Improved', 'Damage_Yes', 'Dmeasure_Yes', 'Dmtype_NonChemical', 'Fert_Yes', 'Fert_No', 'Ferttype_Natural', 'Ferttype_Chemical', 'D23_Manure', 'Fweight', 'Area', 'Production', 'Yield'] if X_test[var].isnull().sum()>0]
# Out:
# []

# %%
# same for train set
[var for var in ['PRECIP', 'TMPMAX', 'TMPMIN', 'RELHUM', 'WINDLY', 'SUNHRS', 'Seed_Not_Improved', 'Damage_Yes', 'Dmeasure_Yes', 'Dmtype_NonChemical', 'Fert_Yes', 'Fert_No', 'Ferttype_Natural', 'Ferttype_Chemical', 'D23_Manure', 'Fweight', 'Area', 'Production', 'Yield'] if X_train[var].isnull().sum()>0]
# Out:
# []

# %%
# let me show you what I mean by monotonic relationship between labels and target
def analyse_vars(df, var):
    df = df.copy()
    df.groupby(var)['Production'].median().plot.bar()
    plt.title(var)
    plt.ylabel('Production')
    plt.show()
    

analyse_vars(X_train, 'Zone')

# %%
analyse_vars(X_train, 'Year')

# %%
train_vars = [var for var in X_train.columns if var not in ['Year', 'Production']]
len(train_vars)
# Out:
# 62

# %%
X_train['Production'].reset_index(drop=True)
# Out:
# 0     12.903378
# 1      9.448307
# 2     12.605173
# 3     12.988448
# 4      7.990631
# 5      9.540889
# 6     13.003955
# 7     12.648976
# 8     12.988852
# 9     12.903378
# 10    11.959552
# 11    10.092737
# 12    10.092737
# 13    11.752283
# 14     9.941215
# 15     8.383559
# 16    10.092737
# 17     8.383559
# 18    12.713769
# 19     8.535722
# 20    12.521155
# 21    12.666965
# 22    12.435808
# 23    12.935073
# 24    12.622974
# 25    12.242954
# 26     8.590624
# 27    13.057845
# 28     8.141758
# 29    12.377143
# 30    10.092737
# 31     8.272067
# 32    12.435808
# 33    10.092737
# 34    12.025024
# 35    10.092737
# 36     8.383559
# 37    10.092737
# 38     7.529943
# 39    11.197919
# 40     8.904069
# Name: Production, dtype: float64

# %%
# fit scaler
scaler = MinMaxScaler() # create an instance
scaler.fit(X_train[train_vars]) #  fit  the scaler to the train set for later use

# transform the train and test set, and add on the Production variables
X_train = pd.concat([X_train[['Production']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(X_train[train_vars]), columns=train_vars)],
                    axis=1)

X_test = pd.concat([X_test[['Production']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(X_test[train_vars]), columns=train_vars)],
                    axis=1)

# %%
X_train.isnull().sum()
# Out:
# Production                0
# Unnamed: 0                0
# Zone                      0
# PRECIP                    0
# TMPMAX                    0
# TMPMIN                    0
# RELHUM                    0
# WINDLY                    0
# SUNHRS                    0
# Irrg_Yes                  0
# Irrg_No                   0
# Seed_Improved             0
# Seed_Not_Improved         0
# Damage_Yes                0
# Damage_No                 0
# Dreason_Crop_disease      0
# Dreason_Frost             0
# Dreason_Floods            0
# Dreason_Locust            0
# Dreason_Insects           0
# Dreason_Toolittle_rain    0
# Dreason_Toomuch_rain      0
# Dreason_Wild_animals      0
# Dreason_Birds             0
# Dreason_Hail              0
# Dreason_Weeds             0
# Dreason_ShortageSeed      0
# Dreason_DepletionSoil     0
# Dreason_Security          0
# Dreason_UseBadCrop        0
#                          ..
# Dmtype_NonChemical        0
# Dmtype_Both               0
# Dmchem_Insecticide        0
# Dmchem_Herbicide          0
# Dmchem_Fungicide          0
# Dmchem_Insectcide_Her     0
# Dmchem_Insectcide_Fun     0
# Dmchem_Herbicide_Fung     0
# Dmchem_All                0
# Fert_Yes                  0
# Fert_No                   0
# Ferttype_Natural          0
# Ferttype_Chemical         0
# Ferttype_Both             0
# D22a_Urea                 0
# D22a_DAP                  0
# D22a_Urea_DAP             0
# D22a_NPS                  0
# D22a_Urea_NPS             0
# D22a_Mixed                0
# D23_Manure                0
# D23_Compost               0
# D23_Organic               0
# D23_Manure_Compost        0
# D23_Manure_Organic        0
# D23_Compost_Organic       0
# D23_All                   0
# Fweight                   0
# Area                      0
# Yield                     0
# Length: 63, dtype: int64

# %%
########################################################################################################################

# %%
# capture the target
y_train = X_train['Production']
y_test = X_test['Production']

# drop unnecessary variables from our training and testing sets
X_train.drop(['Production'], axis=1, inplace=True)
X_test.drop(['Production'], axis=1, inplace=True)

# %%
X_train = X_train.iloc[:, 1:]

# %%
X_train.head()
# Out:
#        Zone    PRECIP    TMPMAX    TMPMIN    RELHUM    WINDLY    SUNHRS  \
# 0  0.666667  0.034001  0.040871  0.196122  0.679708  0.124000  0.150711
# 1  1.000000  0.304812  0.866126  0.757980  0.105311  0.503672  0.330357
# 2  0.333333  0.595532  0.421567  0.691631  0.000000  0.013832  0.985246
# 3  0.666667  0.224974  0.379257  0.541316  0.472807  0.557101  0.522100
# 4  1.000000  0.576202  0.838226  0.822138  0.140257  0.641525  0.567779
#
#    Irrg_Yes   Irrg_No  Seed_Improved  Seed_Not_Improved  Damage_Yes  \
# 0      0.68  0.545491       0.074074           0.551626    0.441259
# 1      0.00  0.013404       0.000000           0.013415    0.003289
# 2      0.28  0.267262       0.037037           0.269919    0.115132
# 3      0.12  0.525995       0.037037           0.527236    0.235432
# 4      0.04  0.028838       0.000000           0.029268    0.009398
#
#    Damage_No  Dreason_Crop_disease  Dreason_Frost  Dreason_Floods  \
# 0   0.517032              0.000000       0.000000        0.452381
# 1   0.037713              0.000000       0.000000        0.000000
# 2   0.515815              0.071795       0.313953        0.357143
# 3   0.975669              0.071795       0.093023        0.214286
# 4   0.069343              0.000000       0.000000        0.023810
#
#    Dreason_Locust  Dreason_Insects  Dreason_Toolittle_rain  \
# 0             0.0         0.000000                0.697379
# 1             0.0         0.000000                0.001589
# 2             0.0         0.043194                0.007943
# 3             0.0         0.001309                0.140588
# 4             0.0         0.000000                0.000000
#
#    Dreason_Toomuch_rain  Dreason_Wild_animals  Dreason_Birds  Dreason_Hail  \
# 0              0.018237              0.032258       0.000000      0.077419
# 1              0.001520              0.064516       0.016667      0.006452
# 2              0.031915              0.645161       0.033333      0.258065
# 3              0.063830              0.516129       0.033333      1.000000
# 4              0.021277              0.000000       0.000000      0.012903
#
#    Dreason_Weeds  Dreason_ShortageSeed  Dreason_DepletionSoil  \
# 0       0.000000                  0.00               0.101124
# 1       0.000000                  0.00               0.011236
# 2       0.132353                  0.25               0.494382
# 3       0.382353                  0.00               0.213483
# 4       0.014706                  0.25               0.022472
#
#    Dreason_Security  Dreason_UseBadCrop  Dmeasure_Yes  Dmeasure_No  \
# 0               0.0            0.134328      0.551570     0.041322
# 1               0.0            0.000000      0.013453     0.000000
# 2               0.0            0.119403      0.233184     0.760331
# 3               0.0            0.000000      0.527110     0.041322
# 4               0.0            0.000000      0.029352     0.000000
#
#    Dmtype_Chemical  Dmtype_NonChemical  Dmtype_Both  Dmchem_Insecticide  \
# 0         0.160714            0.547619     0.013423            0.000000
# 1         0.000000            0.013547     0.000000            0.000000
# 2         0.116071            0.181445     0.610738            0.261905
# 3         0.151786            0.503695     0.335570            0.000000
# 4         0.017857            0.028736     0.006711            0.000000
#
#    Dmchem_Herbicide  Dmchem_Fungicide  Dmchem_Insectcide_Her  \
# 0          0.157407               0.0               0.000000
# 1          0.000000               0.0               0.000000
# 2          0.629630               1.0               0.464286
# 3          0.629630               0.0               0.071429
# 4          0.027778               0.0               0.000000
#
#    Dmchem_Insectcide_Fun  Dmchem_Herbicide_Fung  Dmchem_All  Fert_Yes  \
# 0                    0.0                    0.0         0.0  0.631813
# 1                    0.0                    0.0         0.0  0.014461
# 2                    1.0                    1.0         0.0  0.299778
# 3                    0.0                    0.0         0.0  0.669077
# 4                    0.0                    0.0         0.0  0.023915
#
#     Fert_No  Ferttype_Natural  Ferttype_Chemical  Ferttype_Both  D22a_Urea  \
# 0  0.323657          0.736224           0.338235       0.331066   0.200000
# 1  0.010160          0.024390           0.011029       0.000000   0.000000
# 2  0.181422          0.122855           0.457721       0.358277   0.283333
# 3  0.137881          0.235772           0.933824       1.000000   0.541667
# 4  0.042090          0.011743           0.058824       0.011338   0.000000
#
#    D22a_DAP  D22a_Urea_DAP  D22a_NPS  D22a_Urea_NPS  D22a_Mixed  D23_Manure  \
# 0  0.588710       0.188847       0.0            0.0         0.0    0.627692
# 1  0.000000       0.008872       0.0            0.0         0.0    0.013333
# 2  0.116935       0.435995       0.0            0.0         0.0    0.163077
# 3  1.000000       0.808619       0.0            0.0         0.0    0.298462
# 4  0.004032       0.046895       0.0            0.0         0.0    0.018462
#
#    D23_Compost  D23_Organic  D23_Manure_Compost  D23_Manure_Organic  \
# 0     0.403922     1.000000            1.000000                 0.0
# 1     0.043137     0.000000            0.028708                 0.0
# 2     0.184314     0.209302            0.320574                 0.0
# 3     0.909804     0.023256            0.846890                 0.0
# 4     0.000000     0.000000            0.000000                 0.0
#
#    D23_Compost_Organic   D23_All   Fweight      Area     Yield
# 0             0.000000  0.000000  0.964460  0.951008  0.688277
# 1             0.000000  0.000000  0.064205  0.456267  0.172929
# 2             0.333333  1.000000  0.859795  0.893590  0.680290
# 3             0.000000  0.076923  0.922845  0.959137  0.711004
# 4             0.000000  0.000000  0.165853  0.723336  1.000000

# %%
X_test = X_test.iloc[:, 1:]

# %%
sel_ = SelectFromModel(Lasso(alpha=0.005, random_state=0)) # remember to set the seed, the random state in this function
sel_.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# this command let's us visualise those features that were kept.
# Kept features have a True indicator
sel_.get_support()
# Out:
# array([ True,  True, False, False,  True, False,  True, False, False,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False,  True, False, False, False,  True, False, False,
#        False, False, False, False, False, False,  True, False,  True,
#        False,  True,  True, False, False, False, False,  True, False,
#        False, False, False,  True,  True, False, False,  True, False,
#         True, False, False, False,  True, False,  True])

# %%
# let's print the number of total and selected features

# this is how we can make a list of the selected features
selected_feat = X_train.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 61
# selected features: 19
# features with coefficients shrank to zero: 42

# %%
# print the selected features
selected_feat
# Out:
# Index(['Zone', 'PRECIP', 'RELHUM', 'SUNHRS', 'Damage_No', 'Dreason_Locust',
#        'Dreason_Wild_animals', 'Dreason_ShortageSeed', 'Dmchem_Insecticide',
#        'Dmchem_Fungicide', 'Dmchem_Insectcide_Fun', 'Dmchem_Herbicide_Fung',
#        'Ferttype_Chemical', 'D22a_NPS', 'D22a_Urea_NPS', 'D23_Compost',
#        'D23_Manure_Compost', 'Fweight', 'Yield'],
#       dtype='object')

# %%
# this is an alternative way of identifying the selected features 
# based on the non-zero regularisation coefficients:
selected_feats = X_train.columns[(sel_.estimator_.coef_ != 0).ravel().tolist()]
selected_feats
# Out:
# Index(['Zone', 'PRECIP', 'RELHUM', 'SUNHRS', 'Damage_No', 'Dreason_Locust',
#        'Dreason_Wild_animals', 'Dreason_ShortageSeed', 'Dmchem_Insecticide',
#        'Dmchem_Fungicide', 'Dmchem_Insectcide_Fun', 'Dmchem_Herbicide_Fung',
#        'Ferttype_Chemical', 'D22a_NPS', 'D22a_Urea_NPS', 'D23_Compost',
#        'D23_Manure_Compost', 'Fweight', 'Yield'],
#       dtype='object')

# %%
pd.Series(selected_feats).to_csv('C:/Users/hp/FIN_DATA/selected_featuresBar.csv', index=False)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
# load selected features
# we selected the features in the previous lecture / notebook
# if you haven't done so, go ahead and visit the previous lecture to find out how to select
# the features

features = pd.read_csv('C:/Users/hp/FIN_DATA/selected_featuresBar.csv', header=None)
features = [x for x in features[0]] 

# here I will add this last feature, even though it was not selected in our previous step,
# because it needs key feature engineering steps that I want to discuss further during the deployment
# part of the course. 

features = features + ['Irrg_No'] 

features
# Out:
# ['Zone',
#  'PRECIP',
#  'RELHUM',
#  'SUNHRS',
#  'Damage_No',
#  'Dreason_Locust',
#  'Dreason_Wild_animals',
#  'Dreason_ShortageSeed',
#  'Dmchem_Insecticide',
#  'Dmchem_Fungicide',
#  'Dmchem_Insectcide_Fun',
#  'Dmchem_Herbicide_Fung',
#  'Ferttype_Chemical',
#  'D22a_NPS',
#  'D22a_Urea_NPS',
#  'D23_Compost',
#  'D23_Manure_Compost',
#  'Fweight',
#  'Yield',
#  'Irrg_No']

# %%
# reduce the train and test set to the desired features

X_train = X_train[features]
X_test = X_test[features]

# %%
# train the model
lin_model = Lasso(alpha=0.005, random_state=0) # remember to set the random_state / seed
lin_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.005, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=0,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# evaluate the model:
# remember that we log transformed the output  in our feature engineering notebook / lecture.

# In order to get the true performance of the Lasso
# we need to transform both the target and the predictions
# back to the original agriculture values.

# We will evaluate performance using the mean squared error and the
# root of the mean squared error

pred = lin_model.predict(X_train)
print('linear train mse: {}'.format(mean_squared_error(np.exp(y_train), np.exp(pred))))
print('linear train rmse: {}'.format(sqrt(mean_squared_error(np.exp(y_train), np.exp(pred)))))
print()
pred = lin_model.predict(X_test)
print('linear test mse: {}'.format(mean_squared_error(np.exp(y_test), np.exp(pred))))
print('linear test rmse: {}'.format(sqrt(mean_squared_error(np.exp(y_test), np.exp(pred)))))
print()
print('Average house price: ', np.exp(y_train).median())
# Out:
# linear train mse: 1295299311.102204
# linear train rmse: 35990.26689401183
#
# linear test mse: 11760004422.905033
# linear test rmse: 108443.55408646949
#
# Average house price:  72978.43000000004

# %%
# let's evaluate our predictions respect to the original price
plt.scatter(y_test, lin_model.predict(X_test))
plt.xlabel('True Production')
plt.ylabel('Predicted Production')
plt.title('Evaluation of Lasso Predictions')
# Out:
# Text(0.5, 1.0, 'Evaluation of Lasso Predictions')

# %%
# let's evaluate the distribution of the errors: 
# they should be fairly normally distributed

errors = y_test - lin_model.predict(X_test)
errors.hist(bins=15)

# %%
# Finally, just for fun, let's look at the feature importance

importance = pd.Series(np.abs(lin_model.coef_.ravel()))
importance.index = features
importance.sort_values(inplace=True, ascending=False)
importance.plot.bar(figsize=(18,6))
plt.ylabel('Lasso Coefficients')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')
