# %%
import pandas as pd
import numpy as np

# %%
year1996 = pd.read_csv("C:/Users/hp/CSA_AGRI_DATA/2003 - 2004/Field Information - 1996.csv")
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7,11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
year1996.head()
# Out:
#    reg  zone  dist  fa  ea  hh  pweight hhsize    pratio  hid  ...  alocarea  \
# 0    1     1     2   5   3   1   170.31      2  0.044858    1  ...       .25
# 1    1     1     2   5   3   1   170.31      2  0.044858    1  ...        .5
# 2    1     1     2   5   3   1   170.31      2  0.044858    1  ...      2.25
# 3    1     1     2   5   3   1   170.31      2  0.044858    1  ...         1
# 4    1     1     2   5   3   1   170.31      2  0.044858    1  ...       2.5
#
#   anotmeas enumarea comparea    areah     area plunit  plocal     prodq  \
# 0        5   325.55   325.55  .032555   325.55
# 1        5    671.4   656.52   .06714    671.4     10            7.9225
# 2        5  6693.68  6693.69  .669368  6693.68     30          106.4295
# 3        5  2067.64  2067.64  .206764  2067.64     30           17.3682
# 4        5  6869.62  6869.62  .686962  6869.62     40           87.2442
#
#        prod
# 0
# 1    79.225
# 2  1064.295
# 3   173.682
# 4   872.442
#
# [5 rows x 57 columns]

# %%
def writing(csa_agri_data_version1, writer):
    csa_agri_data_version1.to_excel(writer)

# %%
def featureselection2(csa_year):
    columns = ['reg', 'zone', 'fweight', 'crop', 'irrg', 'trees', 'seedtype', 'damage', 'dreason', 'dpercent', 'dmeasure', 'dmtype', 'dmchem', 'fert', 'ferttype', 'chemtype', 'natutyp', 'apercent', 'enumarea', 'comparea', 'area', 'prodq', 'prod']
    column = ['REG', 'ZONE', 'FWEIGHT', 'CROP', 'IRRG', 'TREES', 'SEEDTYPE', 'DAMAGE', 'DREASON', 'DPERCENT', 'DMEASURE', 'DMTYPE', 'DMCHEM', 'FERT', 'FERTTYPE', 'D22A', 'D23', 'APERCENT', 'ENUMAREA', 'COMPAREA', 'AREA', 'PRODQ', 'PROD']
    csa_agri_data_version1 = pd.ExcelWriter('C:/Users/hp/CSA_AGRI_DATA/csa_data_version1/field_info1_1996.xlsx')
    #csa_agri_data_version1.to_excel(csa_agri_data_version1)
    for col in columns:
        for cols in column:
            csa_agri_data_version1[cols] = csa_year[col]
    return csa_agri_data_version1

# %%
featureselection2(year1996)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-63ab39dc9ee9> in <module>
# ----> 1 featureselection2(year1996)
#
# <ipython-input-19-1a77d3e565e7> in featureselection2(csa_year)
#       6     for col in columns:
#       7         for cols in column:
# ----> 8             csa_agri_data_version1[cols] = csa_year[col]
#       9     return csa_agri_data_version1
#
# TypeError: '_XlsxWriter' object does not support item assignment

# %%
writer = pd.ExcelWriter('C:/Users/hp/CSA_AGRI_DATA/csa_data_version1/field_info1_1996.csv')
writing(writer)
